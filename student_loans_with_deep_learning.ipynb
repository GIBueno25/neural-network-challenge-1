# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"]

# Display a sample of y
y[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop(columns=["credit_ranking"])

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
from sklearn.model_selection import train_test_split

# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler = scaler.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])

# Review the number of features
number_input_features
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 =  6

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = 3

# Define the number of neurons in the output layer
number_output_neurons = 1

# %%
# Create the Sequential model instance
nn = Sequential()

# Add the first hidden layer
nn.add(Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Add the second hidden layer
nn.add(Dense(units=hidden_nodes_layer2, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn.add(Dense(units=number_output_neurons, activation="sigmoid"))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Display the Sequential model summary
nn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 6)                   │              72 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 3)                   │              21 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 97 (388.00 B)
#  Trainable params: 97 (388.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
model_fit = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5135 - loss: 0.7373
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5029 - loss: 0.6852
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5165 - loss: 0.6669
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5654 - loss: 0.6435
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6052 - loss: 0.6445
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6381 - loss: 0.6209
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6547 - loss: 0.6098
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6697 - loss: 0.6092
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7115 - loss: 0.5932
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7107 - loss: 0.5855
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7123 - loss: 0.5928
# Epoch 12/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 0s - 4ms/step - accuracy: 0.7250 - loss: 0.5220
# Loss: 0.5219926238059998, Accuracy: 0.7250000238418579

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path = "student_loans.keras"

# Export your model to a keras file
nn.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = "student_loans.keras"

# Load the model to a new object
from tensorflow.keras.models import load_model
reloaded_model = load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
loan_predictions = reloaded_model.predict(X_test_scaled)

# Display a sample of the predictions
loan_predictions[:5]
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# array([[0.50250363],
#        [0.25513342],
#        [0.862364  ],
#        [0.658975  ],
#        [0.9792341 ]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
loan_predictions_df = pd.DataFrame(loan_predictions, columns=["credit_ranking_predictions"])
loan_predictions_df = loan_predictions_df.round().astype(int)

loan_predictions_df
# Out:
#      credit_ranking_predictions
# 0                             1
# 1                             0
# 2                             1
# 3                             1
# 4                             1
# ..                          ...
# 395                           1
# 396                           0
# 397                           1
# 398                           0
# 399                           1
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
from sklearn.metrics import classification_report
print(classification_report(y_test, loan_predictions_df["credit_ranking_predictions"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.76      0.72       188
#            1       0.77      0.69      0.73       212
#
#     accuracy                           0.72       400
#    macro avg       0.73      0.73      0.72       400
# weighted avg       0.73      0.72      0.73       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**

# %% [markdown]
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
#   Student Demographics and Financial Information:
#         •	Age
#         •	Location
#         •	Education level
#         •	Income
#         •	Debt
#         •	Credit score
#
#      These factors help understand the student's individual circumstances and financial capacity, enabling the system to recommend suitable loan types and repayment plans.
#
#   Loan Information:
#         •	Interest rates
#         •	Loan terms
#         •	Repayment options
#         •	Eligibility criteria
#         •	Lender rating
#         •	Loan forgiveness or deferment option
#
#       This information allows the system to compare and contrast different loan options based on their features and match them with student preferences and needs.
#
#   Student Preferences and Needs:
#         •	Preferred loan amount
#         •	Preferred repayment period
#         •	Preferred monthly payment amounts
#         •	Risk tolerance
#
#      Capturing student preferences ensures the system provides personalized recommendations aligned with their individual financial goals and constraints.
#
#   Historical Loan Data:
#         o	Loan applications
#         o	Loan approvals
#         o	Repayment rates
#         o	Default rates
#
#       This data helps the system learn patterns and identify factors associated with successful loan repayment, allowing it to make more informed recommendations.
#
#   Educational Institution and Program Data:
#         o	Cost of attendance
#         o	Program length
#         o	Graduation rate
#         o	Student debt
#         o	Student repayment rate
#
#       This data helps the system consider factors like program cost, potential future earnings, and career prospects, which influence loan affordability and repayment options.
#
#   The data collected is relevant and appropriate for building a student loan recommendation system because it addresses key factors that influence loan selection and repayment success. By considering individual student circumstances, loan features, preferences, and historical data, the system can provide personalized recommendations that help students make informed financial decisions. The data is also appropriate as it focuses on objective and verifiable information related to student loans and financial well-being, respecting user privacy and ensuring ethical considerations.
#
#   By collecting and analyzing this data, a recommendation system can provide valuable insights and support to students navigating the complex landscape of student loans.
#
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
#   Based on the data recommended above, the model would primarily use content-based filtering approach, with some elements of context-based filtering.
#
#   Content-based filtering would be appropriatre because this approach focuses on recommending student loan options that are similar to those the user has liked or interacted with in the past. It relies heavily on the features of the items and the user's profile. The system can recommend loans with similar interest rates, repayment terms, and other features based on the user's preferences and past choices. Taking into account the student's financial situation allows the system to recommend loans that are likely to be affordable and manageable. The system can also tailor recommendations to the student's specific needs and priorities, such as low interest rates or flexible repayment options. Finally, data can be used to filter loan options based on the student's specific program and institution, ensuring relevance and appropriateness.
#
#   Using elements of context-based filtering allows the system to consider the student's preferences such as minimizing interest payments or maximizing loan forgiveness potential.
#
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.
#
#   Cold-start problem
#   For new users, the system might resort to generic recommendations, which may not be the most suitable or beneficial for their individual circumstances. In addition, new and potentially advantageous loan products might not be recommended due to the lack of historical data, potentially limiting students' access to better options.
#
#   Data sparseness
#   Sparse data can lead to inaccurate recommendations as the system has limited information to learn from. The system may not be able to recommend relevant options for all students, particularly those with niche profiles or those seeking new loan products. Data sparseness can worsen the cold-start problem, making it even more challenging to generate recommendations for new users or new loans.
